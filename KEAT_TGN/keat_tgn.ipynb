# %% [markdown]
# #### Time Encoding ablation. Dataset is tgbl-wiki and time encodings are are GraphMixer, TGN/TGAT and LeTE.

# %% [markdown]
# ### tgbl-wiki: GraphMixer w/o KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py

# L213
# EXP_NAME = 'GM'

# L219
# USE_KERNEL = False

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='GM', use_kernel=False)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: GM
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (172400, 172200), 'gnn': (67800, 67600), 'link_pred': (20301, 20301), 'Model': (260501, 260101)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [00:20<00:00,  5.77it/s]
# INFO: Test: Evaluation Setting: >>> ONE-VS-MANY <<<
# ...

# %% [markdown]
# ### tgbl-wiki: GraphMixer w/ KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py

# L213
# EXP_NAME = 'GM'

# L219
# USE_KERNEL = True

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='GM', use_kernel=True)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: GM_LAP
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (172400, 172200), 'gnn': (67800, 67600), 'link_pred': (20301, 20301), 'Model': (260501, 260101)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [00:20<00:00,  5.69it/s]
# INFO: Test: Evaluation Setting: >>> ONE-VS-MANY <<<
# ...

# %% [markdown]
# ### tgbl-wiki: TGN/TGAT w/o KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py
# In table 4, we have reported from the TGB baseline: https://tgb.complexdatalab.com/docs/leader_linkprop/

# L213
# EXP_NAME = 'TGN'

# L219
# USE_KERNEL = False

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='TGN', use_kernel=False)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: TGN
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (172400, 172400), 'gnn': (67800, 67800), 'link_pred': (20301, 20301), 'Model': (260501, 260501)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [00:21<00:00,  5.62it/s]
# INFO: Test: Evaluation Setting: >>> ONE-VS-MANY <<<
# ...

# %% [markdown]
# ### tgbl-wiki: TGN/TGAT w/ KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py

# L213
# EXP_NAME = 'TGN'

# L219
# USE_KERNEL = True

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='TGN', use_kernel=True)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: TGN_LAP
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (172400, 172400), 'gnn': (67800, 67800), 'link_pred': (20301, 20301), 'Model': (260501, 260501)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [00:21<00:00,  5.61it/s]
# ...

# %% [markdown]
# ### tgbl-wiki: LeTE w/o KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py

# L213
# EXP_NAME = 'LETE'

# L219
# USE_KERNEL = False

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='LETE', use_kernel=False)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: LETE
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (272500, 272500), 'gnn': (167900, 167900), 'link_pred': (20301, 20301), 'Model': (460701, 460701)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [04:09<00:00,  2.09s/it]
# ...

# %% [markdown]
# ### tgbl-wiki: LeTE w/ KEAT

# %%
# we need to set following config manually to ensure compatibility with TGB.
# set following in test.py

# L213
# EXP_NAME = 'LETE'

# L219
# USE_KERNEL = True

# !python test.py
# Out:
# INFO: Arguments: Namespace(data='tgbl-wiki', lr=0.0001, bs=200, k_value=10, num_epoch=200, seed=1, mem_dim=100, time_dim=100, emb_dim=100, tolerance=1e-06, patience=25, num_run=5, time_enc_method='LETE', use_kernel=True)
# raw file found, skipping download
# loading processed file
# ...
# =================*** TGN: LinkPropPred: tgbl-wiki ***=============
# ...
# EXP_NAME: LETE_LAP
# -------------------------------------------------------------------------------
# INFO: >>>>> Run: 0 <<<<<
# INFO: fixed random seed: 1
# ****************************************************************************************************
# Model parameters: (Total, Trainable)
# {'memory': (272500, 272500), 'gnn': (167900, 167900), 'link_pred': (20301, 20301), 'Model': (460701, 460701)}
# ****************************************************************************************************
# ...
# 100%|█████████████████████████████████████████| 119/119 [04:09<00:00,  2.10s/it]
# ...
